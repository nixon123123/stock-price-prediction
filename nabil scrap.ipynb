# %%
import requests
import re
from bs4 import BeautifulSoup

url = "https://www.sharesansar.com/company/NABIL"
posturl = "https://www.sharesansar.com/company-price-history"

start_index = 0
length = 50

body = f"draw=2&columns%5B0%5D%5Bdata%5D=DT_Row_Index&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=false&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=published_date&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=open&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=false&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=high&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=false&columns%5B3%5D%5Borderable%5D=false&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=low&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=false&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=close&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=false&columns%5B5%5D%5Borderable%5D=false&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=per_change&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=false&columns%5B6%5D%5Borderable%5D=false&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=traded_quantity&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=false&columns%5B7%5D%5Borderable%5D=false&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=traded_amount&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=false&columns%5B8%5D%5Borderable%5D=false&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&start={start_index}&length={length}&search%5Bvalue%5D=&search%5Bregex%5D=false&company=16"
try:
    response = requests.get(url)
    if response.ok:
        soup = BeautifulSoup(response.content, "html.parser")
        x_csrf_token = None
        for meta in soup.find_all("meta"):
            if meta.get("name") == "_token":
                x_csrf_token = meta.get("content")
        # print(x_csrf_token)
        cookies = response.headers["Set-Cookie"]
        xsrf = None
        session = None
        match_object = re.match(
            r"(XSRF-TOKEN=.*?);.*?(sharesansar_session=.*?);", cookies
        )
        if match_object:
            xsrf = match_object.group(1)
            session = match_object.group(2)

        headers = {
            "authority": "www.sharesansar.com",
            "method": "POST",
            "path": "/company-price-history",
            "scheme": "https",
            "accept": "application/json, text/javascript, */*; q=0.01",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "en-GB,en;q=0.9",
            "content-length": f"{len(body)}",
            "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Cookie": f"{xsrf}; {session}",
            "origin": "https://www.sharesansar.com",
            "referer": f"{url}",
            "sec-ch-ua": '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Linux"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "same-origin",
            "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36",
            "x-csrf-token": x_csrf_token,
            "x-requested-with": "XMLHttpRequest",
        }

        # print(headers)

        response = requests.post(posturl, data=body, headers=headers)
        table = response.json()["data"]
        for row in table:
            print(row)
        print(len(table))


except Exception as e:
    print(e)
# Out:
# {'published_date': '2023-07-23', 'open': '630.00', 'high': '649.60', 'low': '625.20', 'close': '649.00', 'per_change': '4.01', 'traded_quantity': '147953.00', 'traded_amount': '94121522.80', 'status': 1, 'DT_Row_Index': 1}
# {'published_date': '2023-07-20', 'open': '620.00', 'high': '628.90', 'low': '620.00', 'close': '624.00', 'per_change': '1.17', 'traded_quantity': '124603.00', 'traded_amount': '77783223.10', 'status': 1, 'DT_Row_Index': 2}
# {'published_date': '2023-07-19', 'open': '619.00', 'high': '619.00', 'low': '612.00', 'close': '616.80', 'per_change': '0.62', 'traded_quantity': '76090.00', 'traded_amount': '46874578.90', 'status': 1, 'DT_Row_Index': 3}
# {'published_date': '2023-07-18', 'open': '620.90', 'high': '621.60', 'low': '610.00', 'close': '613.00', 'per_change': '0.33', 'traded_quantity': '76424.00', 'traded_amount': '47031903.00', 'status': 1, 'DT_Row_Index': 4}
# ...

# %%
table
# Out:
# [{'published_date': '2023-07-23',
#   'open': '630.00',
#   'high': '649.60',
#   'low': '625.20',
#   'close': '649.00',
#   'per_change': '4.01',
#   'traded_quantity': '147953.00',
#   'traded_amount': '94121522.80',
#   'status': 1,
#   'DT_Row_Index': 1},
#  {'published_date': '2023-07-20',
#   'open': '620.00',
#   'high': '628.90',
#   'low': '620.00',
#   'close': '624.00',
#   'per_change': '1.17',
#   'traded_quantity': '124603.00',
#   'traded_amount': '77783223.10',
#   'status': 1,
#   'DT_Row_Index': 2},
#  {'published_date': '2023-07-19',
#   'open': '619.00',
#   'high': '619.00',
#   'low': '612.00',
#   'close': '616.80',
#   'per_change': '0.62',
#   'traded_quantity': '76090.00',
#   'traded_amount': '46874578.90',
#   'status': 1,
#   'DT_Row_Index': 3},
#  {'published_date': '2023-07-18',
#   'open': '620.90',
#   'high': '621.60',
#   'low': '610.00',
#   'close': '613.00',
#   'per_change': '0.33',
#   'traded_quantity': '76424.00',
# ...

# %%
import pandas as pd
df=pd.DataFrame(table)

# %%
df
# Out:
#    published_date    open    high     low   close per_change traded_quantity  \
# 0      2023-07-23  630.00  649.60  625.20  649.00       4.01       147953.00
# 1      2023-07-20  620.00  628.90  620.00  624.00       1.17       124603.00
# 2      2023-07-19  619.00  619.00  612.00  616.80       0.62        76090.00
# 3      2023-07-18  620.90  621.60  610.00  613.00       0.33        76424.00
# 4      2023-07-17  607.00  612.00  598.00  611.00       1.97        73868.00
# 5      2023-07-16  595.00  605.90  590.00  599.20       1.56        73028.00
# 6      2023-07-13  574.30  597.90  574.30  590.00       0.68        66352.00
# 7      2023-07-12  585.00  589.90  585.00  586.00       0.51        51194.00
# 8      2023-07-11  584.00  587.00  580.00  583.00       0.00        88236.00
# 9      2023-07-10  593.00  593.00  581.00  583.00       0.00        88478.00
# 10     2023-07-09  590.00  593.60  582.00  583.00       0.15        79385.00
# ...

# %%
df.to_csv('/new proj/nabil recent',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.to_csv('/new proj/nabil recent',index=False)
#
# File ~\.android\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\.android\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
# ...
